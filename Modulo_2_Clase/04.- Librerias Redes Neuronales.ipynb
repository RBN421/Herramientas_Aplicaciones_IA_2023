# %% [markdown]
# <img style="float: left;;" src='Figures/alinco.png' /></a>
#
# # <center> <font color= #000047> Módulo 2: Redes Neuronales Librería

# %% [markdown]
# - La derivación es el aspecto algorítmicamente más costoso en la utilización de clasificadores basados en redes neuronales.
#
# - Calcular las decenas, centenares o centenares de miles de derivadas parciales sería una tarea abrumadora si la tuviéramos que resolver a mano cada vez que construimos una red neuronal.
#
# - Afortunadamente contamos con herramientas que hacen eficientemente esa labor por nosotros. **Keras** es una de ellas.

# %% [markdown]
# ## Keras
#
# [Keras](https://keras.io/) es una API escrita en Python que nos permite de una forma rápida y cómoda configurar y entrenar redes neuronales.
#
# <img src="Figures/keras-logo.png" width="30%">
#
# - Hay otra cosa que Keras hace por nosotros y que es sumamente importante: trasladar el cálculo a la GPU en lugar de hacerlo en la CPU. Todo el cálculo que realiza la red para generar una salida es computacionalmente muy alto. Son muchísimas las multiplicaciones y sumas que se llevan a cabo. Pero, afortunadamente, la inmensa mayoría de estas operaciones son paralelizables. Y, de la misma forma que los juegos actuales utilizan la GPU para poder mover rápidamente una inmensa cantidad de puntos, vértices y polígonos, esta misma arquitectura de computación paralela se adapta perfectamente a las necesidades de cálculo de las redes neuronales.
#
# - Por supuesto, cuando las redes y sus conjuntos de datos son pequeños no es indispensable disponer de GPU en el ordenador. Pero en cuanto el modelo o los datos crecen el tiempo de cómputo se vuelve crucial.
#
# **Keras, a su vez, se apoya sobre otras herramientas como [Tensorflow](https://www.tensorflow.org/) y [CUDA](https://developer.nvidia.com/cuda-zone) (si disponemos de GPU).**

# %% [markdown]
# ## Instalación
#
# Visita [https://keras.io/#installation](https://keras.io/#installation) para instalar Keras. Antes debes [instalar Tensorflow](https://www.tensorflow.org/install).
#
# **Modo rápido:** Si quieres, puedes realizar una instalación limpia de Keras mediante un entorno virtual (recomendable).
#
# **Instala ambiente virtual con Anaconda**
#
# Desde consola:
#
# <code>conda create -n nombre_de_tu_entorno</code>
#
# Crea el entorno virtual
#
# <code>conda create -n nombre_de_tu_entorno python=3.6</code>
#
# Activa el entorno virtual
#
# <code>conda activate nombre_de_tu_entorno<\code>
#
# Dentro del entorno, instala Tensorflow:
#
# <code>pip install tensorflow</code>
#
# y luego, Keras:
#
# <code>pip install keras</code>
#
# Con esto tendrás una instalación de Keras para realizar las prácticas, pero sin GPU. Si tu ordenador no tiene GPU, entonces será la opción adecuada.
#
# Podemos instalar todas las librerías que necesitemos como pandas, numpy, matplotlib
#
# <code>pip install keras</code>
# <code>pip install pandas</code>
# <code>pip install matplotlib</code>
#
# **Añadir el Ambiente virtual a Jupyter Notebook**
#
# Jupyter Notebook se asegura de que el kernel de IPython esté disponible, pero se debe agregar manualmente un kernel con una versión diferente de Python o un entorno virtual.
#
# -Primero, necesitamos activar su entorno virtual.
#
# -A continuación, instalaremos ipykernel, que proporciona el kernel de IPython para Jupyter:
#
# <code>pip install --user ipykernel</code>
#
# Ahora se pude añadir un ambiente virtual a jupyter con el siguiente comando:
#
# <code>python -m ipykernel install --user --name=myenv</code>
#
# Ahora podemos elegir el entorno conda como Kernel en Jupyter.

# %% [markdown]
# ### Modelo
#
# La estructura principal de Keras es el **modelo**, lo cual es una forma de organizar y conectar capas de neuronas. El tipo de modelo más simple es el **modelo secuencial**, que es una pila lineal de capas. Para arquitecturas más complejas, es necesario utilizar la **API funcional** de Keras, que permite crear capas con conexiones arbitrarias.

# %%
import pandas as pd
import numpy as np

# %%
# Creamos nuestro modelo
from tensorflow import keras

# %%
from tensorflow.keras.models import Sequential

# %% [markdown]
# Ahora apilaremos capas con <code>.add()</code>. Keras denomina a las capas neuronales básicas como **densas** <code>Dense</code>, lo que significa que todas las entradas son conectadas a todas las neuronas. Como observamos en la figura siguiente, todas las $n$ entradas se conectan a todas las $m$ neuronas. Veremos más adelante que esto no siempre es así. Hay capas denominadas **convolutivas** que no siguen este patrón de conexión, sino que parte de las entradas se conectan solo a algunas neuronas de la capa. Pero, por ahora, eso es otra historia.
#
# <img src="Figures/densa.svg" width="30%">
#
# Fíjate que en la instanciación de la primera capa densa tenemos que especificar el número de entradas <code>input_dim=4</code>, pero en la siguiente capa no. Keras sabe que son $5$ entradas puesto que en la capa anterior hay $5$ neuronas <code>units=5</code>

# %%
model = Sequential()

# %%
#Creando la arquitectura de la red neuronal
#importar dense
from tensorflow.keras.layers import Dense
# capa con 4 entradas
model.add(Dense(input_dim=4, units=5, activation = 'sigmoid')) #4 entradas conectadas a 5 neuronas
# capa con 5 neuronas
model.add(Dense(units = 3, activation = 'softmax')) # 5 entradas conectadas a 3 neuronas

# %% [markdown]
# ### Configuración del entrenamiento
#
# Una vez configurado el modelo, especificaremos el proceso de aprendizaje.
#
# - La **función de error** o **pérdida** (**loss**) que utilizaremos es <code>loss='mse'</code>, lo que significa *mean squared error* o error cuadrático medio. Es parecida a la suma de todos los errores que ya hemos visto pero dividido por el número de muestras sobre las que calculamos el error.
#
# - En cuando al optimizador, usaremos el clásico gradiente descendente <code>optimizer=keras.optimizers.SGD(lr=1)</code> (stochastic gradient descent) al que le aplicamos un *learning rate* o **tasa de aprendizaje** de $1$.
#
# \- Lo de *gradiante descendente*, ya lo sabemos. Pero, ¿lo de *estocástico* qué significa?
#
# En este contexto, **estocástico** significa que no vamos a calcular el error sobre todo el conjunto de muestras en cada iteración sino sobre un subconjunto **aleatorio** de ellos. Ese subconjunto corresponde al *mini-batch* que ya vimos.
#
# Durante el proceso de entrenamiento vamos progresivamente descendiendo por la función de error hasta llegar a algún mínimo. Para verificar que vamos avanzando adecuadamente es conveniente ir comprobando cómo el valor de la función de error va bajando (*loss*). Sin embargo, *loss* es un valor que no indica nada en sí, solo que si baja es buena señal. Pero, lo que realmente nos va diciendo cuánto vamos mejorando es el *accuracy* (precisión) <code>metrics=['accuracy']</code>. Este valor se calcula introduciendo las muestras en la red y comprobando qué porcentaje de ellas ha clasificado correctamente.

# %%
# compilar el modelo
model.compile(loss='mse', optimizer=keras.optimizers.SGD(lr=1), metrics=['accuracy'])

# %% [markdown]
# ### Preparación de los datos. Entrenamiento y test
#
# Una vez completamente definido el modelo y cómo lo vamos a entrenar es necesario preparar los datos sobre los que vamos a trabajar. Esta vez vamos a dividir nuestro conjunto de muestras en dos subconjuntos: uno  para **entrenar** (*train*) y otro para **verificar** (*test*). Cuando entrenamos una red neuronal con un conjunto de muestras, ¿cómo podemos estar seguros de que esa red es capaz de clasificar correctamente nuevas muestras que nunca haya visto antes? Dicho de otro modo, ¿cómo podemos saber si la red puede **generalizar**?
#
# Para saber si una red ha aprendido correctamente hacemos esta división. Vamos a entrenar la red con el **conjunto de entrenamiento**. Y una vez entrenada comprobaremos cuántas muestras del **conjunto de test** es capaz de clasificar correctamente. Si el porcentaje de aciertos es satisfactorio concluimos que la red está correctamente entrenada.

# %%
# Cargamos el dataset iris
data_iris = pd.read_csv('Data/iris.data', header=None)
data_iris['out'] = data_iris.iloc[:,4].astype('category').cat.codes
data_iris.head(3)
# Etiquetas en formato one-hot

# Particionando la data Tomamos el 80% (120) de las muestras para entrenar y el 20% (30) para testear
# Out:
#      0    1    2    3            4  out
# 0  5.1  3.5  1.4  0.2  Iris-setosa    0
# 1  4.9  3.0  1.4  0.2  Iris-setosa    0
# 2  4.7  3.2  1.3  0.2  Iris-setosa    0

# %%
data_iris = data_iris.values

# %%
#desordenar el dataset
np.random.shuffle(data_iris)

# %%
# Creación de la función one-hot
def one_hot(x, n):
    if type(x)==list:
        x = np.array(x)
    x = x.flatten()
    o_h = np.zeros((len(x),n))
    o_h[np.arange(len(x)), x]=1
    return o_h

# %%
x_data = data_iris[:,:4].astype(float)
y_data = one_hot(data_iris[:,5].astype(int), 3)

# %%
# Partición de las muestras 80% para el train, y el 20% test
x_train = x_data[:120]
x_test = x_data[120:]

y_train = y_data[:120]
y_test = y_data[120:]

# %% [markdown]
# ### Entrenamiento
#
# Procedemos a hacer el entrenamiento de la red. Para ello solo tenemos que invocar al método <code>fit</code> del modelo y especificarle que queremos entrenar $200$ épocas y que use un tamaño de lote de $15$.

# %%
# fit del modelo
history = model.fit(x_train, y_train, epochs=200, batch_size=15)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 0s 750us/step - loss: 0.2419 - accuracy: 0.4000
# Epoch 2/200
# 8/8 [==============================] - 0s 750us/step - loss: 0.1974 - accuracy: 0.5417
# Epoch 3/200
# 8/8 [==============================] - 0s 625us/step - loss: 0.1682 - accuracy: 0.6167
# Epoch 4/200
# 8/8 [==============================] - 0s 627us/step - loss: 0.1510 - accuracy: 0.6917
# Epoch 5/200
# 8/8 [==============================] - 0s 625us/step - loss: 0.1382 - accuracy: 0.6833
# Epoch 6/200
# 8/8 [==============================] - 0s 750us/step - loss: 0.1292 - accuracy: 0.6917
# Epoch 7/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.1203 - accuracy: 0.7333
# Epoch 8/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1137 - accuracy: 0.8000
# Epoch 9/200
# 8/8 [==============================] - 0s 750us/step - loss: 0.1069 - accuracy: 0.8083
# Epoch 10/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.1107 - accuracy: 0.7000
# Epoch 11/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.1092 - accuracy: 0.7083
# Epoch 12/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0970 - accuracy: 0.8667
# Epoch 13/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.0979 - accuracy: 0.8083
# Epoch 14/200
# 8/8 [==============================] - 0s 624us/step - loss: 0.0898 - accuracy: 0.8833
# Epoch 15/200
# 8/8 [==============================] - 0s 750us/step - loss: 0.1006 - accuracy: 0.8417
# Epoch 16/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.0890 - accuracy: 0.8333
# Epoch 17/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.0942 - accuracy: 0.8083
# Epoch 18/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0861 - accuracy: 0.8083
# Epoch 19/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.0894 - accuracy: 0.8083
# Epoch 20/200
# 8/8 [==============================] - 0s 749us/step - loss: 0.0864 - accuracy: 0.8667
# Epoch 21/200
# 8/8 [==============================] - 0s 626us/step - loss: 0.0806 - accuracy: 0.8417
# Epoch 22/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.0661 - accuracy: 0.9250
# Epoch 23/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0633 - accuracy: 0.8917
# Epoch 24/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0786 - accuracy: 0.8250
# Epoch 25/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0842 - accuracy: 0.7917
# Epoch 26/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.0658 - accuracy: 0.8917
# Epoch 27/200
# 8/8 [==============================] - 0s 500us/step - loss: 0.0608 - accuracy: 0.8917
# Epoch 28/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0597 - accuracy: 0.9167
# Epoch 29/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0479 - accuracy: 0.9417
# Epoch 30/200
# 8/8 [==============================] - 0s 625us/step - loss: 0.0721 - accuracy: 0.8833
# Epoch 31/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.0496 - accuracy: 0.9417
# Epoch 32/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0917 - accuracy: 0.8000
# Epoch 33/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0677 - accuracy: 0.8667
# Epoch 34/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0751 - accuracy: 0.8417
# Epoch 35/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.0451 - accuracy: 0.9583
# Epoch 36/200
# 8/8 [==============================] - 0s 748us/step - loss: 0.0452 - accuracy: 0.9417
# Epoch 37/200
# 8/8 [==============================] - 0s 873us/step - loss: 0.0486 - accuracy: 0.9167
# Epoch 38/200
# 8/8 [==============================] - 0s 750us/step - loss: 0.0519 - accuracy: 0.8917
# Epoch 39/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.0658 - accuracy: 0.8417
# Epoch 40/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.0394 - accuracy: 0.9500
# Epoch 41/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.0329 - accuracy: 0.9417
# Epoch 42/200
# 8/8 [==============================] - 0s 750us/step - loss: 0.0364 - accuracy: 0.9500
# Epoch 43/200
# 8/8 [==============================] - 0s 625us/step - loss: 0.0412 - accuracy: 0.9333
# Epoch 44/200
# 8/8 [==============================] - 0s 874us/step - loss: 0.0514 - accuracy: 0.8917
# Epoch 45/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0361 - accuracy: 0.9417
# Epoch 46/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.0503 - accuracy: 0.9083
# Epoch 47/200
# 8/8 [==============================] - 0s 749us/step - loss: 0.0316 - accuracy: 0.9500
# Epoch 48/200
# 8/8 [==============================] - 0s 876us/step - loss: 0.0410 - accuracy: 0.9167
# Epoch 49/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0489 - accuracy: 0.9000
# Epoch 50/200
# 8/8 [==============================] - 0s 750us/step - loss: 0.0306 - accuracy: 0.9500
# Epoch 51/200
# 8/8 [==============================] - 0s 690us/step - loss: 0.0451 - accuracy: 0.9083
# Epoch 52/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.0315 - accuracy: 0.9500
# Epoch 53/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0288 - accuracy: 0.9583
# Epoch 54/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.0238 - accuracy: 0.9833
# Epoch 55/200
# 8/8 [==============================] - 0s 942us/step - loss: 0.0229 - accuracy: 0.9667
# Epoch 56/200
# 8/8 [==============================] - 0s 564us/step - loss: 0.0397 - accuracy: 0.9333
# Epoch 57/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0417 - accuracy: 0.9333
# Epoch 58/200
# 8/8 [==============================] - 0s 815us/step - loss: 0.0446 - accuracy: 0.9083
# Epoch 59/200
# 8/8 [==============================] - 0s 624us/step - loss: 0.0598 - accuracy: 0.8750
# Epoch 60/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0242 - accuracy: 0.9583
# Epoch 61/200
# 8/8 [==============================] - 0s 625us/step - loss: 0.0307 - accuracy: 0.9500
# Epoch 62/200
# 8/8 [==============================] - 0s 750us/step - loss: 0.0289 - accuracy: 0.9667
# Epoch 63/200
# 8/8 [==============================] - 0s 625us/step - loss: 0.0340 - accuracy: 0.9583
# Epoch 64/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0412 - accuracy: 0.9167
# Epoch 65/200
# 8/8 [==============================] - 0s 625us/step - loss: 0.0260 - accuracy: 0.9667
# Epoch 66/200
# 8/8 [==============================] - 0s 625us/step - loss: 0.0379 - accuracy: 0.9167
# Epoch 67/200
# 8/8 [==============================] - 0s 624us/step - loss: 0.0268 - accuracy: 0.9500
# Epoch 68/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0240 - accuracy: 0.9583
# Epoch 69/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.0349 - accuracy: 0.9250
# Epoch 70/200
# 8/8 [==============================] - 0s 625us/step - loss: 0.0207 - accuracy: 0.9750
# Epoch 71/200
# 8/8 [==============================] - 0s 500us/step - loss: 0.0220 - accuracy: 0.9667
# Epoch 72/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0345 - accuracy: 0.9250
# Epoch 73/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0310 - accuracy: 0.9417
# Epoch 74/200
# 8/8 [==============================] - 0s 625us/step - loss: 0.0247 - accuracy: 0.9417
# Epoch 75/200
# 8/8 [==============================] - 0s 625us/step - loss: 0.0368 - accuracy: 0.9167
# Epoch 76/200
# 8/8 [==============================] - 0s 750us/step - loss: 0.0680 - accuracy: 0.8583
# Epoch 77/200
# 8/8 [==============================] - 0s 750us/step - loss: 0.0524 - accuracy: 0.8917
# Epoch 78/200
# 8/8 [==============================] - 0s 751us/step - loss: 0.0347 - accuracy: 0.9167
# Epoch 79/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0248 - accuracy: 0.9667
# Epoch 80/200
# 8/8 [==============================] - 0s 625us/step - loss: 0.0334 - accuracy: 0.9333
# Epoch 81/200
# 8/8 [==============================] - 0s 638us/step - loss: 0.0225 - accuracy: 0.9667
# Epoch 82/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0268 - accuracy: 0.9417
# Epoch 83/200
# 8/8 [==============================] - 0s 625us/step - loss: 0.0384 - accuracy: 0.9250
# Epoch 84/200
# 8/8 [==============================] - 0s 750us/step - loss: 0.0310 - accuracy: 0.9417
# Epoch 85/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.0191 - accuracy: 0.9667
# Epoch 86/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.0367 - accuracy: 0.9000
# Epoch 87/200
# 8/8 [==============================] - 0s 750us/step - loss: 0.0225 - accuracy: 0.9667
# Epoch 88/200
# 8/8 [==============================] - 0s 750us/step - loss: 0.0268 - accuracy: 0.9417
# Epoch 89/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.0209 - accuracy: 0.9750
# Epoch 90/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0209 - accuracy: 0.9750
# Epoch 91/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0247 - accuracy: 0.9583
# Epoch 92/200
# 8/8 [==============================] - 0s 750us/step - loss: 0.0250 - accuracy: 0.9500
# Epoch 93/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0309 - accuracy: 0.9417
# Epoch 94/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.0245 - accuracy: 0.9500
# Epoch 95/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0175 - accuracy: 0.9833
# Epoch 96/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.0224 - accuracy: 0.9583
# Epoch 97/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0268 - accuracy: 0.9417
# Epoch 98/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 0.9750
# Epoch 99/200
# 8/8 [==============================] - 0s 625us/step - loss: 0.0339 - accuracy: 0.9333
# Epoch 100/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0190 - accuracy: 0.9667
# Epoch 101/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0186 - accuracy: 0.9583
# Epoch 102/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0229 - accuracy: 0.9667
# Epoch 103/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0165 - accuracy: 0.9667
# Epoch 104/200
# 8/8 [==============================] - 0s 750us/step - loss: 0.0209 - accuracy: 0.9583
# Epoch 105/200
# 8/8 [==============================] - 0s 999us/step - loss: 0.0161 - accuracy: 0.9750
# Epoch 106/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0222 - accuracy: 0.9583
# Epoch 107/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0402 - accuracy: 0.9083
# Epoch 108/200
# 8/8 [==============================] - 0s 625us/step - loss: 0.0167 - accuracy: 0.9750
# Epoch 109/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0215 - accuracy: 0.9500
# Epoch 110/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0345 - accuracy: 0.9333
# Epoch 111/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0193 - accuracy: 0.9583
# Epoch 112/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0143 - accuracy: 0.9833
# Epoch 113/200
# 8/8 [==============================] - 0s 750us/step - loss: 0.0196 - accuracy: 0.9667
# Epoch 114/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0268 - accuracy: 0.9417
# Epoch 115/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0152 - accuracy: 0.9667
# Epoch 116/200
# 8/8 [==============================] - 0s 749us/step - loss: 0.0234 - accuracy: 0.9500
# Epoch 117/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0245 - accuracy: 0.9500
# Epoch 118/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0222 - accuracy: 0.9583
# Epoch 119/200
# 8/8 [==============================] - 0s 750us/step - loss: 0.0190 - accuracy: 0.9750
# Epoch 120/200
# 8/8 [==============================] - 0s 625us/step - loss: 0.0131 - accuracy: 0.9750
# Epoch 121/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0368 - accuracy: 0.9250
# Epoch 122/200
# 8/8 [==============================] - 0s 750us/step - loss: 0.0268 - accuracy: 0.9500
# Epoch 123/200
# 8/8 [==============================] - 0s 627us/step - loss: 0.0218 - accuracy: 0.9667
# Epoch 124/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0212 - accuracy: 0.9583
# Epoch 125/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0214 - accuracy: 0.9500
# Epoch 126/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0158 - accuracy: 0.9667
# Epoch 127/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0509 - accuracy: 0.9083
# Epoch 128/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0255 - accuracy: 0.9417
# Epoch 129/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.0199 - accuracy: 0.9583
# Epoch 130/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0184 - accuracy: 0.9583
# Epoch 131/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0260 - accuracy: 0.9583
# Epoch 132/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0358 - accuracy: 0.9333
# Epoch 133/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0408 - accuracy: 0.9083
# Epoch 134/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0273 - accuracy: 0.9500
# Epoch 135/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.0149 - accuracy: 0.9833
# Epoch 136/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.0176 - accuracy: 0.9667
# Epoch 137/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0246 - accuracy: 0.9500
# Epoch 138/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.0155 - accuracy: 0.9750
# Epoch 139/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0257 - accuracy: 0.9500
# Epoch 140/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.0177 - accuracy: 0.9667
# Epoch 141/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0180 - accuracy: 0.9667
# Epoch 142/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0189 - accuracy: 0.9667
# Epoch 143/200
# 8/8 [==============================] - 0s 625us/step - loss: 0.0207 - accuracy: 0.9750
# Epoch 144/200
# 8/8 [==============================] - 0s 873us/step - loss: 0.0195 - accuracy: 0.9750
# Epoch 145/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 0.9667
# Epoch 146/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0379 - accuracy: 0.9250
# Epoch 147/200
# 8/8 [==============================] - 0s 750us/step - loss: 0.0203 - accuracy: 0.9667
# Epoch 148/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 0.9583
# Epoch 149/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0275 - accuracy: 0.9500
# Epoch 150/200
# 8/8 [==============================] - 0s 625us/step - loss: 0.0201 - accuracy: 0.9500
# Epoch 151/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0184 - accuracy: 0.9667
# Epoch 152/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0137 - accuracy: 0.9750
# Epoch 153/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0180 - accuracy: 0.9667
# Epoch 154/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0171 - accuracy: 0.9667
# Epoch 155/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0174 - accuracy: 0.9583
# Epoch 156/200
# 8/8 [==============================] - 0s 816us/step - loss: 0.0259 - accuracy: 0.9417
# Epoch 157/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0169 - accuracy: 0.9750
# Epoch 158/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0175 - accuracy: 0.9667
# Epoch 159/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0251 - accuracy: 0.9417
# Epoch 160/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0147 - accuracy: 0.9667
# Epoch 161/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0216 - accuracy: 0.9667
# Epoch 162/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0192 - accuracy: 0.9583
# Epoch 163/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.0144 - accuracy: 0.9750
# Epoch 164/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 0.9583
# Epoch 165/200
# 8/8 [==============================] - 0s 624us/step - loss: 0.0169 - accuracy: 0.9667
# Epoch 166/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0151 - accuracy: 0.9667
# Epoch 167/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0205 - accuracy: 0.9583
# Epoch 168/200
# 8/8 [==============================] - 0s 750us/step - loss: 0.0168 - accuracy: 0.9750
# Epoch 169/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 1.00 - 0s 1ms/step - loss: 0.0193 - accuracy: 0.9667
# Epoch 170/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0201 - accuracy: 0.9583
# Epoch 171/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.0169 - accuracy: 0.9667
# Epoch 172/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 0.9583
# Epoch 173/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0297 - accuracy: 0.9250
# Epoch 174/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0151 - accuracy: 0.9833
# Epoch 175/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.0190 - accuracy: 0.9583
# Epoch 176/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0176 - accuracy: 0.9667
# Epoch 177/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0174 - accuracy: 0.9583
# Epoch 178/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0190 - accuracy: 0.9583
# Epoch 179/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.0172 - accuracy: 0.9750
# Epoch 180/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0458 - accuracy: 0.8917
# Epoch 181/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0132 - accuracy: 0.9833
# Epoch 182/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0245 - accuracy: 0.9500
# Epoch 183/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0132 - accuracy: 0.9750
# Epoch 184/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0142 - accuracy: 0.9667
# Epoch 185/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0140 - accuracy: 0.9750
# Epoch 186/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 0.9583
# Epoch 187/200
# 8/8 [==============================] - 0s 750us/step - loss: 0.0162 - accuracy: 0.9750
# Epoch 188/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0267 - accuracy: 0.9417
# Epoch 189/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0176 - accuracy: 0.9583
# Epoch 190/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0131 - accuracy: 0.9833
# Epoch 191/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.0220 - accuracy: 0.9583
# Epoch 192/200
# 8/8 [==============================] - 0s 625us/step - loss: 0.0202 - accuracy: 0.9583
# Epoch 193/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.0260 - accuracy: 0.9333
# Epoch 194/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0136 - accuracy: 0.9833
# Epoch 195/200
# 8/8 [==============================] - 0s 750us/step - loss: 0.0189 - accuracy: 0.9667
# Epoch 196/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.0125 - accuracy: 0.9750
# Epoch 197/200
# 8/8 [==============================] - 0s 750us/step - loss: 0.0166 - accuracy: 0.9667
# Epoch 198/200
# 8/8 [==============================] - 0s 875us/step - loss: 0.0139 - accuracy: 0.9750
# Epoch 199/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0201 - accuracy: 0.9583
# Epoch 200/200
# 8/8 [==============================] - 0s 751us/step - loss: 0.0151 - accuracy: 0.9750

# %% [markdown]
# ### Visualización
#
# El objeto <code>history</code> que nos devuelve el método <code>fit</code> contiene la información acerca del progreso del entrenamiento. Vemos cómo el valor de *loss* va decreciendo mientras el *accuracy* va aproximándose a $1$, lo que representa casi el 100% de las muestras de entramiento bien clasificadas.

# %%
history.history['loss']
# Out:
# [0.24187541007995605,
#  0.19738884270191193,
#  0.16824617981910706,
#  0.15098123252391815,
#  0.13819251954555511,
#  0.12917107343673706,
#  0.12026330083608627,
#  0.11374056339263916,
#  0.10686266422271729,
#  0.11072776466608047,
#  0.1092301681637764,
#  0.0970393642783165,
#  0.09787169843912125,
#  0.08982411026954651,
#  0.10063157975673676,
#  0.08899733424186707,
#  0.09415814280509949,
#  0.0860772579908371,
#  0.08935297280550003,
#  0.08640681207180023,
#  0.08060812950134277,
#  0.06607147306203842,
#  0.06328032165765762,
#  0.07864093780517578,
#  0.08415259420871735,
#  0.06578931212425232,
#  0.06083012744784355,
#  0.05972524732351303,
#  0.04786745458841324,
#  0.07206905633211136,
#  0.04963840916752815,
#  0.09167995303869247,
#  0.06768854707479477,
#  0.07513533532619476,
#  0.04505334794521332,
#  0.04519021883606911,
#  0.04855834320187569,
#  0.05189172923564911,
#  0.06579949706792831,
#  0.03938795253634453,
#  0.03285617381334305,
#  0.036379702389240265,
#  0.04124626889824867,
#  0.05140143260359764,
#  0.03610914200544357,
#  0.0502643845975399,
#  0.03164009004831314,
#  0.041011858731508255,
#  0.048873838037252426,
#  0.03061409667134285,
#  0.0450587272644043,
#  0.031542543321847916,
#  0.028788061812520027,
#  0.023798206821084023,
#  0.022864587604999542,
#  0.03969525545835495,
#  0.04170776531100273,
#  0.044608697295188904,
#  0.059843648225069046,
#  0.02419232949614525,
#  0.03074752539396286,
#  0.028880080208182335,
#  0.03402785211801529,
#  0.041159335523843765,
#  0.025977065786719322,
#  0.03786977380514145,
#  0.026826776564121246,
#  0.023989124223589897,
#  0.0349414087831974,
#  0.020740194246172905,
#  0.02202947624027729,
#  0.03454716131091118,
#  0.030972106382250786,
#  0.02465519681572914,
#  0.03683122619986534,
#  0.06800851970911026,
#  0.05236539989709854,
#  0.034661099314689636,
#  0.024764101952314377,
#  0.03344732150435448,
#  0.022474050521850586,
#  0.02679833024740219,
#  0.0384209081530571,
#  0.031012842431664467,
#  0.019098402932286263,
#  0.03668154776096344,
#  0.0225105881690979,
#  0.026807237416505814,
#  0.02094368264079094,
#  0.020881038159132004,
#  0.024656351655721664,
#  0.02501818723976612,
#  0.030856691300868988,
#  0.024504901841282845,
#  0.017514444887638092,
#  0.022377608343958855,
#  0.02676653303205967,
#  0.016621919348835945,
#  0.03391053527593613,
#  0.018987813964486122,
#  0.018580814823508263,
#  0.022873075678944588,
#  0.016535041853785515,
#  0.02088611200451851,
#  0.016071025282144547,
#  0.022249571979045868,
#  0.04019176959991455,
#  0.016680676490068436,
#  0.021459871903061867,
#  0.034464430063962936,
#  0.019252073019742966,
#  0.01428262796252966,
#  0.0195731483399868,
#  0.02676134929060936,
#  0.015236510895192623,
#  0.02338920347392559,
#  0.024477560073137283,
#  0.022221872583031654,
#  0.019013170152902603,
#  0.01312166266143322,
#  0.03681444004178047,
#  0.02679494395852089,
#  0.02179168350994587,
#  0.021172115579247475,
#  0.021427804604172707,
#  0.015819039195775986,
#  0.0509040392935276,
#  0.025527896359562874,
#  0.019867397844791412,
#  0.018402408808469772,
#  0.025977006182074547,
#  0.03583028167486191,
#  0.0408298559486866,
#  0.027297623455524445,
#  0.014903767965734005,
#  0.01758601889014244,
#  0.024586129933595657,
#  0.015517736785113811,
#  0.025684790685772896,
#  0.017658444121479988,
#  0.01800786331295967,
#  0.018890146166086197,
#  0.0207399670034647,
#  0.01945433020591736,
#  0.014438446611166,
#  0.03790644556283951,
#  0.020277414470911026,
#  0.01878618448972702,
#  0.027451306581497192,
#  0.020130613818764687,
#  0.01841571554541588,
#  0.013726532459259033,
#  0.017984913662075996,
#  0.01711905747652054,
#  0.01742854155600071,
#  0.025879614055156708,
#  0.01685611717402935,
#  0.017468009144067764,
#  0.02511548064649105,
#  0.014697551727294922,
#  0.02155406028032303,
#  0.019240444526076317,
#  0.01441923063248396,
#  0.019235167652368546,
#  0.016873799264431,
#  0.01513492688536644,
#  0.020540650933980942,
#  0.016806114464998245,
#  0.01930106058716774,
#  0.02011750265955925,
#  0.01687314733862877,
#  0.016576461493968964,
#  0.02967008575797081,
#  0.015106379985809326,
#  0.019010890275239944,
#  0.01764795556664467,
#  0.017352156341075897,
#  0.018967624753713608,
#  0.01719724014401436,
#  0.045811522752046585,
#  0.013226221315562725,
#  0.02446931228041649,
#  0.013233130797743797,
#  0.014229608699679375,
#  0.013963238336145878,
#  0.01878388412296772,
#  0.016236472874879837,
#  0.02666284516453743,
#  0.017591124400496483,
#  0.013070096261799335,
#  0.021998079493641853,
#  0.020240716636180878,
#  0.025952478870749474,
#  0.013567465357482433,
#  0.018896231427788734,
#  0.012485587038099766,
#  0.01655799336731434,
#  0.013924244791269302,
#  0.020093480125069618,
#  0.015059355646371841]

# %%
#visualización de los datos
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(6,4))
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['accuracy'], label='accuracy')
plt.title('Entrenamiento del dataset Iris')
plt.xlabel('Epocas')
plt.ylabel('loss vs accuracy')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### Test
#
# Durante el entrenamiento *accuracy* nos indica el porcentaje de aciertos sobre el mismo conjunto de entrenamiento. Pero nos interesa conocer el porcentaje de acierto sobre un conjunto no visto antes por la red. Para ello utilizamos el conjunto de test.

# %%
#test de la clasificación
model.evaluate(x_test, y_test, verbose=1)
# Out:
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0217 - accuracy: 0.9667
# [0.02170800045132637, 0.9666666388511658]

# %% [markdown]
# ### Predicción
#
# Una vez entrenada y testeada la red, podemos ponerla en producción. Keras tiene funciones para guardar tanto el modelo como los pesos ya entrenados. Si queremos hacer una clasifiación invocaremos el método <code>predict</code> del modelo.
#
# Vamos a ver qué resultados nos ofrece la red si introducimos el conjunto de test.

# %%
# predicción 
model.weights
# Out:
# [<tf.Variable 'dense/kernel:0' shape=(4, 5) dtype=float32, numpy=
#  array([[ 0.36636436, -0.5973542 , -1.7058663 ,  1.7552307 ,  0.8206244 ],
#         [ 1.5093688 , -0.8386259 , -2.5542686 ,  2.811278  ,  0.7864868 ],
#         [-2.3739192 ,  1.7391009 ,  3.0826144 , -3.336249  ,  0.06354582],
#         [-0.836125  , -0.02967625,  3.358346  , -3.465269  , -0.5345416 ]],
#        dtype=float32)>,
#  <tf.Variable 'dense/bias:0' shape=(5,) dtype=float32, numpy=
#  array([ 0.14581363, -0.29582483, -1.4318016 ,  1.4815521 ,  0.01543544],
#        dtype=float32)>,
#  <tf.Variable 'dense_1/kernel:0' shape=(5, 3) dtype=float32, numpy=
#  array([[ 2.8471985 , -2.9068136 , -1.5262318 ],
#         [-2.5993123 ,  0.14927809,  1.339756  ],
#         [-0.99167204, -1.7094735 ,  2.4502237 ],
#         [ 1.7600808 ,  1.489743  , -3.2915258 ],
#         [-0.01629438,  1.0776149 , -0.4368056 ]], dtype=float32)>,
#  <tf.Variable 'dense_1/bias:0' shape=(3,) dtype=float32, numpy=array([-0.59950936,  0.42706957,  0.17244029], dtype=float32)>]

# %%
model.predict(x_test)
# Out:
# array([[1.3012302e-03, 7.6590374e-02, 9.2210835e-01],
#        [9.7626561e-01, 2.3600744e-02, 1.3369850e-04],
#        [2.0466936e-03, 1.0081193e-01, 8.9714134e-01],
#        [2.3098318e-02, 9.5173234e-01, 2.5169225e-02],
#        [9.7110277e-01, 2.8736927e-02, 1.6034277e-04],
#        [8.2167663e-04, 3.9876204e-02, 9.5930213e-01],
#        [7.9866796e-04, 4.4533897e-02, 9.5466739e-01],
#        [1.7448865e-02, 8.4737378e-01, 1.3517737e-01],
#        [1.1258867e-02, 5.9983718e-01, 3.8890395e-01],
#        [9.7449458e-01, 2.5362717e-02, 1.4273891e-04],
#        [9.7486895e-01, 2.4988621e-02, 1.4231518e-04],
#        [9.7365391e-01, 2.6197718e-02, 1.4838039e-04],
#        [9.7670913e-01, 2.3159416e-02, 1.3139471e-04],
#        [2.9237294e-03, 1.4505196e-01, 8.5202432e-01],
#        [2.0177361e-02, 9.5060617e-01, 2.9216476e-02],
#        [1.9302815e-03, 9.2935577e-02, 9.0513420e-01],
#        [4.5284368e-02, 9.5041060e-01, 4.3051448e-03],
#        [2.3452405e-02, 9.6101457e-01, 1.5533021e-02],
#        [9.7660112e-01, 2.3266770e-02, 1.3215025e-04],
#        [5.6423503e-04, 3.0773213e-02, 9.6866256e-01],
#        [1.6590834e-02, 8.9119565e-01, 9.2213616e-02],
#        [6.9602428e-04, 3.7320346e-02, 9.6198362e-01],
#        [2.6721166e-02, 9.6482211e-01, 8.4567601e-03],
#        [2.4688581e-02, 9.4583333e-01, 2.9478189e-02],
#        [4.9770955e-04, 2.9563310e-02, 9.6993893e-01],
#        [2.2894219e-02, 9.6413589e-01, 1.2969826e-02],
#        [2.2238337e-02, 9.6909887e-01, 8.6627509e-03],
#        [2.0221227e-03, 9.7563542e-02, 9.0041429e-01],
#        [2.2943990e-02, 9.4382215e-01, 3.3233907e-02],
#        [4.5700386e-04, 2.8068312e-02, 9.7147465e-01]], dtype=float32)

# %% [markdown]
# ## Ejercicio
#
# - Varía algunos hiperparámetros (learning rate, tamaño del mini-lote, número de neuronas en la capa oculta, número de épocas) y observa qué ocurre.
