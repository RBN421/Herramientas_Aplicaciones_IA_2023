# %%
import pandas as pd
import numpy as np

# %%
df_bank = pd.read_csv('Data/bank.csv')

# %%
from HAIA import HyAIA as hya

# %%
hy1 = hya(df_bank)

# %%
hy1.data
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
hy1.remove_punctuation('jasjd,i)---')
# Out:
# 'jasjdi'

# %%
df_dirty = pd.read_csv('Data/dirty_data.csv')

# %%
df_dirty['people'].apply(hy1.remove_punctuation).apply(hy1.remove_digits)
# Out:
# 0                      Alfonso Aguilar
# 1                     eduardo Castillo
# 2                        jocelyn medel
# 3                      VICTOR ramos
# 4        CARLOS EDUARDO OCHOA ARAMBULA
# 5           JOSE MANUEL OCHOA CARDENAS
# 6             JUAN MARIO OCHOA NAVARRO
# 7                LUIS ONTANEDA MIJARES
# 8          EDUARDO OMAR ORTEGA RAMIREZ
# 9      JOSE ALEJANDRO PRECIADO GANDARA
# 10    Jose Aantonio Quintero Rodriguez
# 11              JOSE ALFONSO RAMIREZ D
# 12              ANA PAULA RANGEL OCHOA
# 13                  Arturo RUIZ CHAVEZ
# Name: people, dtype: object

# %%
hy1.dqr
# Out:
#           Columns_Names  Dtypes  Present_values  Missing_values  \
# age                 age   int64            4521               0
# job                 job  object            4521               0
# marital         marital  object            4521               0
# education     education  object            4521               0
# default         default  object            4521               0
# balance         balance   int64            4521               0
# housing         housing  object            4521               0
# loan               loan  object            4521               0
# contact         contact  object            4521               0
# day                 day   int64            4521               0
# month             month  object            4521               0
# duration       duration   int64            4521               0
# campaign       campaign   int64            4521               0
# pdays             pdays   int64            4521               0
# ...
